# %%
#Kinetica webinar
#11/10/2017
#Kaggle Credit Scoring dataset
#https://www.kaggle.com/c/GiveMeSomeCredit/data
"""
Give Me Some Credit
Improve on the state of the art in credit scoring by 
predicting the probability that somebody will experience financial distress in the next two years.
"""

import pandas as pd
# %matplotlib inline

# %%
df=pd.read_csv("myData/CreditScoring-training.csv")
df.head()
# Out:
#    Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0           1                 1                              0.766127   45
# 1           2                 0                              0.957151   40
# 2           3                 0                              0.658180   38
# 3           4                 0                              0.233810   30
# 4           5                 0                              0.907239   49
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                     2   0.802982         9120.0
# 1                                     0   0.121876         2600.0
# 2                                     1   0.085113         3042.0
# 3                                     0   0.036050         3300.0
# 4                                     1   0.024926        63588.0
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# count  150000.000000     150000.000000                         150000.000000
# mean    75000.500000          0.066840                              6.048438
# std     43301.414527          0.249746                            249.755371
# min         1.000000          0.000000                              0.000000
# 25%     37500.750000          0.000000                              0.029867
# 50%     75000.500000          0.000000                              0.154181
# 75%    112500.250000          0.000000                              0.559046
# max    150000.000000          1.000000                          50708.000000
#
#                  age  NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  \
# count  150000.000000                         150000.000000  150000.000000
# mean       52.295207                              0.421033     353.005076
# ...

# %%
df.columns
# Out:
# Index([u'Unnamed: 0', u'SeriousDlqin2yrs',
#        u'RevolvingUtilizationOfUnsecuredLines', u'age',
#        u'NumberOfTime30-59DaysPastDueNotWorse', u'DebtRatio', u'MonthlyIncome',
#        u'NumberOfOpenCreditLinesAndLoans', u'NumberOfTimes90DaysLate',
#        u'NumberRealEstateLoansOrLines',
#        u'NumberOfTime60-89DaysPastDueNotWorse', u'NumberOfDependents'],
#       dtype='object')

# %%
df.drop('Unnamed: 0', axis=1)
# Out:
#         SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0                      1                              0.766127   45
# 1                      0                              0.957151   40
# 2                      0                              0.658180   38
# 3                      0                              0.233810   30
# 4                      0                              0.907239   49
# 5                      0                              0.213179   74
# 6                      0                              0.305682   57
# 7                      0                              0.754464   39
# 8                      0                              0.116951   27
# 9                      0                              0.189169   57
# 10                     0                              0.644226   30
# 11                     0                              0.018798   51
# 12                     0                              0.010352   46
# ...

# %%
df.SeriousDlqin2yrs.value_counts()
# Out:
# 0    139974
# 1     10026
# Name: SeriousDlqin2yrs, dtype: int64

# %%
df.SeriousDlqin2yrs.value_counts().plot.bar()

# %%
ex_pivot=df.pivot_table(values='SeriousDlqin2yrs', index='NumberOfDependents', aggfunc='mean')
ex_pivot.sort_values('SeriousDlqin2yrs', ascending=False)
# Out:
#                     SeriousDlqin2yrs
# NumberOfDependents
# 6.0                         0.151899
# 4.0                         0.103774
# 7.0                         0.098039
# 5.0                         0.091153
# 3.0                         0.088263
# 8.0                         0.083333
# 2.0                         0.081139
# 1.0                         0.073529
# 0.0                         0.058629
# 9.0                         0.000000
# 10.0                        0.000000
# 13.0                        0.000000
# 20.0                        0.000000

# %%
df.MonthlyIncome.hist()

# %%
len(df[df.MonthlyIncome>20000])
# Out:
# 2103

# %%
len(df[df.DebtRatio>1.5])
# Out:
# 32073

# %%
df[df.DebtRatio>1.5]['SeriousDlqin2yrs'].value_counts()
# Out:
# 0    30195
# 1     1878
# Name: SeriousDlqin2yrs, dtype: int64

# %%
adf = df[df.DebtRatio<=1.5]
bdf = adf[adf.MonthlyIncome<=20000]
len(bdf)
# Out:
# 114001

# %%
cdf = bdf.dropna()

# %%
cdf.to_csv("myData/CreditScoring_training_tidy.csv", index=False)
